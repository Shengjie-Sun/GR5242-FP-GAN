# %% [markdown]
# # Deep Convolutional Generative Adversarial Network

# %% [markdown]
# ## Step 0: Setup

# %% [markdown]
# ### Import Packages

# %%
# !pip uninstall tensorflow
# pip install tensorflow-gpu
import os
import glob
import datetime

import imageio
from PIL import Image
from IPython import display
import matplotlib.pyplot as plt

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers

print("%d GPUs are available for tensorflow %s in current environment." % 
      (len(tf.config.experimental.list_physical_devices('GPU')), tf.__version__))
# %load_ext tensorboard
# Out:
# 0 GPUs are available for tensorflow 2.0.0 in current environment.

# %% [markdown]
# ### Set the Paths of the Outputs

# %%
# get the dictionary for the project
pwd = os.path.dirname(os.getcwd())
# set and create the path for log file for tesnorboard
log_dir = os.path.join(pwd, 'outputs', 'logs')
os.makedirs(log_dir, exist_ok = True)
# set and create the path for saving the images
image_dir = os.path.join(pwd, 'outputs', 'images')
os.makedirs(image_dir, exist_ok = True)
# set and create the path for saving the weights of the model
checkpoint_dir = os.path.join(pwd, 'outputs', 'checkpoints')
os.makedirs(checkpoint_dir, exist_ok = True)

# %%
# the time stamp
stamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
structure = 'GAN'
dataset = 'MNIST'
config = "%s-%s-%s" % (structure, dataset, stamp)
config
# Out:
# 'GAN-MNIST-20191124-143738'

# %% [markdown]
# ### Load and Prepare the Dataset

# %%
# load mnist data
(mnist_train, _), (mnist_val, _) = tf.keras.datasets.mnist.load_data()
# load svhn data
svhn_train = tfds.load("svhn_cropped", with_info=False, as_supervised=True, split=tfds.Split.TRAIN)
svhn_val = tfds.load("svhn_cropped", with_info=False, as_supervised=True, split=tfds.Split.TEST)

# %%
def mnist_preprocess(x):        
    x = 2*tf.cast(x, dtype=tf.float32)/255 - 1
    # expand the 3d tensor to 4d
    x = tf.expand_dims(x, axis=-1)
    return x

def svhn_preprocess(x, y):        
    x = 2*tf.cast(x, dtype=tf.float32)/255 - 1      
    return x

# %%
mnist_train_db = tf.data.Dataset.from_tensor_slices(mnist_train).map(mnist_preprocess).shuffle(60000)
mnist_val_db = tf.data.Dataset.from_tensor_slices(mnist_val).map(mnist_preprocess)
svhn_train_db = svhn_train.map(svhn_preprocess).shuffle(60000)
svhn_val_db = svhn_val.map(svhn_preprocess).shuffle(60000)

# %%
# get one batch and check the dimension of this batch
mnist_samples = next(iter(mnist_val_db.batch(16)))
print("shape of one batch for MNIST images is: " + str(mnist_samples.shape))
svhn_samples = next(iter(svhn_val_db.batch(16)))
print("shape of one batch for SVHN images is: " + str(svhn_samples.shape))
# Out:
# shape of one batch for MNIST images is: (16, 28, 28, 1)
# shape of one batch for SVHN images is: (16, 32, 32, 3)

# %% [markdown]
# ## Step 2: Define the Generator and Discriminator

# %% [markdown]
# ### The Generator

# %%
class Generator(tf.keras.Model):
    
    def __init__(self):
        super().__init__()
        
        self.fc0 = layers.Dense(7*7*256, use_bias=False)
        self.bn0 = layers.BatchNormalization()
        
        self.conv1 = layers.Conv2DTranspose(filters=128, kernel_size=5, strides=1, padding='same', use_bias=False)
        self.bn1 = layers.BatchNormalization()
        
        self.conv2 = layers.Conv2DTranspose(filters=64, kernel_size=5, strides=2, padding='same', use_bias=False)
        self.bn2 = layers.BatchNormalization()
        
        self.conv3 = layers.Conv2DTranspose(filters=1, kernel_size=5, strides=2, padding='same', use_bias=False)
         
    def call(self, inputs, training=None):
        x = self.fc0(inputs)   
        # assert x.shape == (BATCH, 7*7*256)
        x = tf.reshape(x, [-1, 7, 7, 256]) 
        x = tf.nn.leaky_relu(x)
        
        x = tf.nn.leaky_relu(self.bn1(self.conv1(x), training=training))
        # assert x.shape == (BATCH, 7, 7, 128)
        
        x = tf.nn.leaky_relu(self.bn2(self.conv2(x), training=training))
        # assert x.shape == (BATCH, 14, 14, 64)
        
        image = tf.math.tanh(self.conv3(x))
        # assert image.shape == (BATCH, 28, 28, 1)
        
        return image

# %%
generator = Generator()
seed = tf.random.normal([32, 100])
image_fake = generator(seed, training=False)
print("The shape of the output of the generator is: " + str(image_fake.shape))
# Out:
# The shape of the output of the generator is: (32, 28, 28, 1)

# %%
plt.imshow(image_fake[0, :, :, 0], cmap='gray')
plt.show()

# %% [markdown]
# ### The Discriminator

# %%
class Discriminator(tf.keras.Model):
    
    def __init__(self):
        super().__init__()
        self.conv1 = layers.Conv2D(filters=64, kernel_size=5, strides=2, padding='same')
        self.dropout1 = layers.Dropout(0.3)
        
        self.conv2 = layers.Conv2D(filters=128, kernel_size=5, strides=2, padding='same')
        self.bn2 = layers.BatchNormalization()
        self.dropout2 = layers.Dropout(0.3)
        
        self.conv3 = layers.Conv2D(filters=256, kernel_size=5, strides=2, padding='same')
        self.bn3 = layers.BatchNormalization()
        self.dropout3 = layers.Dropout(0.3)
        
        self.flatten = layers.Flatten()
        self.fc = layers.Dense(1)
        
    def call(self, inputs, training=None):
        x = tf.nn.leaky_relu(self.dropout1(self.conv1(inputs)))
        x = self.dropout2(tf.nn.leaky_relu(self.bn2(self.conv2(x), training=training)))
        x = self.dropout3(tf.nn.leaky_relu(self.bn3(self.conv3(x), training=training)))
        
        x = self.flatten(x)
        logits = self.fc(x)
        
        return logits

# %%
discriminator = Discriminator()
logits = discriminator(image_fake, training=False)
print("The shape of logits given by discriminator is: " + str(logits.shape))
# Out:
# The shape of logits given by discriminator is: (32, 1)

# %% [markdown]
# ## Step 3: Define some Helper Functions

# %%
loss_cal = tf.losses.BinaryCrossentropy(from_logits=True)

# %% [markdown]
# ### Discriminator Loss Calculator

# %%
def discriminator_loss_cal(generator, discriminator, seed, image_true, training):
    
    image_fake = generator(seed, training)
    
    # treat real image as real
    logits_real = discriminator(image_true, training)
    loss_real = tf.reduce_mean(loss_cal(tf.ones_like(logits_real), logits_real))
    # treat fake image as fake
    logits_fake = discriminator(image_fake, training)
    loss_fake = tf.reduce_mean(loss_cal(tf.zeros_like(logits_fake), logits_fake))  
    loss = loss_fake + loss_real
    
    return loss

# %% [markdown]
# ### Generator Loss Calculator

# %%
def generator_loss_cal(generator, discriminator, seed, training):
    
    image_fake = generator(seed, training)
    logits_fake = discriminator(image_fake, training)
    
    loss = tf.reduce_mean(loss_cal(tf.ones_like(logits_fake), logits_fake))     
    return loss

# %% [markdown]
# ### Image Saver

# %%
def save_image(images, height, width, image_path, index):

    images = ((images + 1.0) * 127.5).astype(np.uint8)
    # final picture which save as PNG
    picture = np.array([])
    
    row = np.array([])
    for i in range(height*width):
        # concat image into a row
        if row.size == 0:
            row = images[i]
        else:
            row = np.concatenate((row, images[i]), axis=1)

        # concat image row to picture
        if (i+1) % width == 0:
            if picture.size == 0:
                picture = row
            else:
                picture = np.concatenate((picture, row), axis=0)
            # reset single row
            row = np.array([])
    
    picture_board = tf.expand_dims(tf.cast(picture, dtype=tf.uint8), 0)
    with summary_writer.as_default(): 
        tf.summary.image('train-fake-images:', picture_board, step=index)
    
    picture = np.squeeze(picture, axis=2)
    Image.fromarray(picture, 'P').save(image_path)

# %% [markdown]
# ### Step 4: Define the Training Loop

# %%
# number of epochs
EPOCH = 1
BATCH = 32
# step size, i.e. number of batches per validation
STEP = 5
SAVE = 3

SEED = 100
LEARNING_RATE_D = 1e-3
LEARNING_RATE_G = 1e-3

# %%
if dataset == 'MNIST':
    train_db = mnist_train_db.batch(BATCH, drop_remainder=True)
    val_db = mnist_val_db.batch(BATCH, drop_remainder=True)
else:
    train_db = svhn_train_db.batch(BATCH, drop_remainder=True)
    val_db = svhn_val_db.batch(BATCH, drop_remainder=True)

# %%
generator_optimizer = tf.optimizers.Adam(learning_rate=LEARNING_RATE_G)
discriminator_optimizer = tf.optimizers.Adam(learning_rate=LEARNING_RATE_D)

# %%
# save the training process
checkpoint_prefix = os.path.join(checkpoint_dir, config, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# the log file created for tensorborad for this time of training
cur_log_dir = os.path.join(log_dir, config)
summary_writer = tf.summary.create_file_writer(cur_log_dir) 
# the file for saving images for this time of training
cur_image_dir = os.path.join(image_dir, config)
os.makedirs(cur_image_dir, exist_ok = True)
# if you want to see the visualization during the traing, run this line
# %tensorboard --logdir=log_dir

# %%
# number of batches have trained
index = -1
for epoch in range(EPOCH):
    
    for step, image_true in enumerate(train_db):
        
        seed = tf.random.uniform([BATCH, SEED], minval=-1, maxval=1)
        # train Discriminator
        with tf.GradientTape() as tape:
            discriminator_loss = discriminator_loss_cal(generator, discriminator, seed, image_true, training=True)
        grads = tape.gradient(discriminator_loss, discriminator.trainable_weights)
        discriminator_optimizer.apply_gradients(zip(grads, discriminator.trainable_weights))
        
        # train Generator
        with tf.GradientTape() as tape:
            generator_loss = generator_loss_cal(generator, discriminator, seed, training=True)
        grads = tape.gradient(generator_loss, generator.trainable_weights)
        generator_optimizer.apply_gradients(zip(grads, generator.trainable_weights))     
        
        if step % STEP == 0:
            index += 1
            print("At epoch: %s/%d, after %s batches have been trained: discriminator loss: %.5f, generator loss: %.5f" % 
                  (format(epoch, '2'), EPOCH, format(step,'2'), float(discriminator_loss), float(generator_loss)))
            
            with summary_writer.as_default(): 
                tf.summary.scalar('train-generator-loss', float(generator_loss), step=index) 
                tf.summary.scalar('train-discriminator-loss', float(discriminator_loss), step=index) 
                
            fake_image = generator(seed, training=False)
            image_path = os.path.join(cur_image_dir, 'after-%d-batches.png' % index)
            save_image(fake_image.numpy(), 5, 5, image_path, index)
    
    if epoch % SAVE == 0:
        checkpoint.save(file_prefix = checkpoint_prefix)
# Out:
# At epoch:  0/1, after  0 batches have been trained: discriminator loss: 1.87978, generator loss: 1.21938
# At epoch:  0/1, after  5 batches have been trained: discriminator loss: 7.08414, generator loss: 8.01912
# At epoch:  0/1, after 10 batches have been trained: discriminator loss: 1.04422, generator loss: 11.69952
# At epoch:  0/1, after 15 batches have been trained: discriminator loss: 1.75519, generator loss: 8.57964
# At epoch:  0/1, after 20 batches have been trained: discriminator loss: 0.56603, generator loss: 10.54860
# At epoch:  0/1, after 25 batches have been trained: discriminator loss: 0.48993, generator loss: 10.63020
# At epoch:  0/1, after 30 batches have been trained: discriminator loss: 0.59471, generator loss: 9.60431
# At epoch:  0/1, after 35 batches have been trained: discriminator loss: 0.31420, generator loss: 7.70577
# At epoch:  0/1, after 40 batches have been trained: discriminator loss: 0.08540, generator loss: 6.82387
# At epoch:  0/1, after 45 batches have been trained: discriminator loss: 0.34737, generator loss: 6.25511
# At epoch:  0/1, after 50 batches have been trained: discriminator loss: 0.04710, generator loss: 8.52868
# At epoch:  0/1, after 55 batches have been trained: discriminator loss: 0.28323, generator loss: 5.96631
# At epoch:  0/1, after 60 batches have been trained: discriminator loss: 0.58839, generator loss: 5.39700
# At epoch:  0/1, after 65 batches have been trained: discriminator loss: 0.19327, generator loss: 7.67545
# At epoch:  0/1, after 70 batches have been trained: discriminator loss: 0.08918, generator loss: 5.56630
# At epoch:  0/1, after 75 batches have been trained: discriminator loss: 0.21106, generator loss: 11.86452
# At epoch:  0/1, after 80 batches have been trained: discriminator loss: 0.20024, generator loss: 10.29276
# At epoch:  0/1, after 85 batches have been trained: discriminator loss: 0.09336, generator loss: 9.10994
# At epoch:  0/1, after 90 batches have been trained: discriminator loss: 0.06208, generator loss: 7.56913
# At epoch:  0/1, after 95 batches have been trained: discriminator loss: 0.15135, generator loss: 5.25995
# At epoch:  0/1, after 100 batches have been trained: discriminator loss: 0.09527, generator loss: 6.67883
# At epoch:  0/1, after 105 batches have been trained: discriminator loss: 0.46336, generator loss: 4.29877
# At epoch:  0/1, after 110 batches have been trained: discriminator loss: 0.06637, generator loss: 7.47081
# At epoch:  0/1, after 115 batches have been trained: discriminator loss: 0.04874, generator loss: 5.22575
# At epoch:  0/1, after 120 batches have been trained: discriminator loss: 0.15750, generator loss: 10.08486
# At epoch:  0/1, after 125 batches have been trained: discriminator loss: 0.28838, generator loss: 8.93005
# At epoch:  0/1, after 130 batches have been trained: discriminator loss: 0.04265, generator loss: 7.41503
# At epoch:  0/1, after 135 batches have been trained: discriminator loss: 0.01323, generator loss: 8.59179
# At epoch:  0/1, after 140 batches have been trained: discriminator loss: 0.01422, generator loss: 11.09332
# At epoch:  0/1, after 145 batches have been trained: discriminator loss: 0.01536, generator loss: 10.05315
# At epoch:  0/1, after 150 batches have been trained: discriminator loss: 0.05804, generator loss: 9.00622
# At epoch:  0/1, after 155 batches have been trained: discriminator loss: 0.02159, generator loss: 6.92365
# At epoch:  0/1, after 160 batches have been trained: discriminator loss: 0.00278, generator loss: 9.34761
# At epoch:  0/1, after 165 batches have been trained: discriminator loss: 0.00307, generator loss: 9.11868
# At epoch:  0/1, after 170 batches have been trained: discriminator loss: 0.00479, generator loss: 8.56777
# At epoch:  0/1, after 175 batches have been trained: discriminator loss: 0.00088, generator loss: 10.84103
# At epoch:  0/1, after 180 batches have been trained: discriminator loss: 0.01374, generator loss: 10.40946
# At epoch:  0/1, after 185 batches have been trained: discriminator loss: 0.00423, generator loss: 7.77289
# At epoch:  0/1, after 190 batches have been trained: discriminator loss: 0.00782, generator loss: 6.78918
# At epoch:  0/1, after 195 batches have been trained: discriminator loss: 0.00034, generator loss: 9.89631
# At epoch:  0/1, after 200 batches have been trained: discriminator loss: 0.00049, generator loss: 12.33257
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-fe9f8fb9f67f> in <module>
#       8         # train Discriminator
#       9         with tf.GradientTape() as tape:
# ---> 10             discriminator_loss = discriminator_loss_cal(generator, discriminator, seed, image_true, training=True)
#      11         grads = tape.gradient(discriminator_loss, discriminator.trainable_weights)
#      12         discriminator_optimizer.apply_gradients(zip(grads, discriminator.trainable_weights))
#
# <ipython-input-17-e6099796bc68> in discriminator_loss_cal(generator, discriminator, seed, image_true, training)
#       7     loss_real = tf.reduce_mean(loss_cal(tf.ones_like(logits_real), logits_real))
#       8     # treat fake image as fake
# ----> 9     logits_fake = discriminator(image_fake, training)
#      10     loss_fake = tf.reduce_mean(loss_cal(tf.zeros_like(logits_fake), logits_fake))
#      11     loss = loss_fake + loss_real
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# <ipython-input-14-8e89523ff9b3> in call(self, inputs, training)
#      18
#      19     def call(self, inputs, training=None):
# ---> 20         x = tf.nn.leaky_relu(self.dropout1(self.conv1(inputs)))
#      21         x = self.dropout2(tf.nn.leaky_relu(self.bn2(self.conv2(x), training=training)))
#      22         x = self.dropout3(tf.nn.leaky_relu(self.bn3(self.conv3(x), training=training)))
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\layers\core.py in call(self, inputs, training)
#     164     output = tf_utils.smart_cond(training,
#     165                                  dropped_inputs,
# --> 166                                  lambda: array_ops.identity(inputs))
#     167     return output
#     168
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\utils\tf_utils.py in smart_cond(pred, true_fn, false_fn, name)
#      57         pred, true_fn=true_fn, false_fn=false_fn, name=name)
#      58   return smart_module.smart_cond(
# ---> 59       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#      60
#      61
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      52   if pred_value is not None:
#      53     if pred_value:
# ---> 54       return true_fn()
#      55     else:
#      56       return false_fn()
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\keras\layers\core.py in dropped_inputs()
#     160           noise_shape=self._get_noise_shape(inputs),
#     161           seed=self.seed,
# --> 162           rate=self.rate)
#     163
#     164     output = tf_utils.smart_cond(training,
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\util\deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\ops\nn_ops.py in dropout(x, keep_prob, noise_shape, seed, name, rate)
#    4227     raise ValueError("You must provide a rate to dropout.")
#    4228
# -> 4229   return dropout_v2(x, rate, noise_shape=noise_shape, seed=seed, name=name)
#    4230
#    4231
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\ops\nn_ops.py in dropout_v2(x, rate, noise_shape, seed, name)
#    4306     # and subtract 1.0.
#    4307     random_tensor = random_ops.random_uniform(
# -> 4308         noise_shape, seed=seed, dtype=x.dtype)
#    4309     keep_prob = 1 - rate
#    4310     scale = 1 / keep_prob
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\ops\random_ops.py in random_uniform(shape, minval, maxval, dtype, seed, name)
#     244     else:
#     245       rnd = gen_random_ops.random_uniform(shape, dtype, seed=seed1, seed2=seed2)
# --> 246       result = math_ops.add(rnd * (maxval - minval), minval, name=name)
#     247     # TODO(b/132092188): C++ shape inference inside functional ops does not
#     248     # cross FuncGraph boundaries since that information is only available in
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\ops\math_ops.py in binary_op_wrapper(x, y)
#     897     with ops.name_scope(None, op_name, [x, y]) as name:
#     898       if isinstance(x, ops.Tensor) and isinstance(y, ops.Tensor):
# --> 899         return func(x, y, name=name)
#     900       elif not isinstance(y, sparse_tensor.SparseTensor):
#     901         try:
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\ops\math_ops.py in _mul_dispatch(x, y, name)
#    1204   is_tensor_y = isinstance(y, ops.Tensor)
#    1205   if is_tensor_y:
# -> 1206     return gen_math_ops.mul(x, y, name=name)
#    1207   else:
#    1208     assert isinstance(y, sparse_tensor.SparseTensor)  # Case: Dense * Sparse.
#
# D:\Anaconda3\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py in mul(x, y, name)
#    6682       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#    6683         _ctx._context_handle, _ctx._thread_local_data.device_name, "Mul",
# -> 6684         name, _ctx._post_execution_callbacks, x, y)
#    6685       return _result
#    6686     except _core._FallbackException:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 5: Visualization

# %% [markdown]
# ### Greate GIFs

# %%
# set the path of the GIF file
anime_path = os.path.join(cur_image_dir, "%s-%s.%s" % (structure, dataset, 'gif'))
# create the GIF with imageio
with imageio.get_writer(anime_path, mode='I') as writer:
    filenames = glob.glob(os.path.join(cur_image_dir, '*.png'))
    filenames = sorted(filenames)
    last = -1
    for i,filename in enumerate(filenames):
        frame = 2*(i**0.5)
        if round(frame) > round(last):
            last = frame
        else:
            continue
        image = imageio.imread(filename)
        writer.append_data(image)
    image = imageio.imread(filename)
    writer.append_data(image)
# show the GIF in the notebook
display.Image(filename=anime_path)

# %% [markdown]
# ### Tensor Board

# %%
# %tensorboard --logdir=log_dir
